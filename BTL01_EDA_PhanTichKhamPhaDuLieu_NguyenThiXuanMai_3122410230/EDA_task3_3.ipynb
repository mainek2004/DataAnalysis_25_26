# %% [markdown]
# # Nhiệm vụ 1: Sử dụng pandas profiling

# %% [markdown]
# ##Import thư viện

# %%
import os
import pandas as pd
from ydata_profiling import ProfileReport
marketing_data = pd.read_csv('/content/drive/MyDrive/DataAnalysis/Tuần 5/marketing_campaign.csv')
profile = ProfileReport(marketing_data, title="Report")
os.makedirs("Reports", exist_ok=True)
profile.to_file("/content/drive/MyDrive/DataAnalysis/Tuần 5/Report/profile_output.html")
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00,  5.76it/s]
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.savefig(
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/visualisation/utils.py:73: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.savefig(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Nhiệm vụ 2: Sử dụng dtale trên dữ liệu Marketing Campaign.

# %%
import pandas as pd
import dtale
marketing_data = pd.read_csv("/content/drive/MyDrive/DataAnalysis/Tuần 5/marketing_campaign.csv")
dtale.show(marketing_data)
# Out:
# http://19aeeb013621:40000/dtale/main/12
